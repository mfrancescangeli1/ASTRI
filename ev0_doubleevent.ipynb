# %%
import matplotlib.pyplot as plt
import astricaltools as at
import numpy as np
import pandas as pd
import scipy.stats as sc
from astropy import stats
import astropy.units as u
from astropy.io import fits
from astropy.table import vstack, Table
from astropy.time import Time
from astropy.timeseries import TimeSeries
from astropy.coordinates import SkyCoord, EarthLocation, AltAz, Angle

# %%
file_numbers = range(1, 10)  # da 001 a 009
base_path = "astri_{:03d}_43_009_00002_R_201023_004_0201_SEB.lv0"  # pattern del nome file

dfs = []  # lista per accumulare i DataFrame
print("\n")
for i in file_numbers:
    filename = base_path.format(i)
    print(f"{filename}")

    with at.io.fits.AstriFits(filename) as hdul:
        data = hdul[1].data

        # Conversione dei campi
        time_ns = data["TIME_NS"].byteswap().newbyteorder().astype(np.int64)
        time_s  = data["TIME_S"].byteswap().newbyteorder().astype(np.int64)
        event   = data["EVTNUM"].byteswap().newbyteorder().astype(np.int64)
        mcrun   = data["MCRUNNUM"].byteswap().newbyteorder().astype(np.int64)
        time_abs = time_s * 10**9 + time_ns  # tempo assoluto in ns
        hg, lg, ttp = hdul.get_data('events', ['hi', 'lo', 'ttp'])
        time_abs = time_s * 10**9 + time_ns  # tempo assoluto in ns
            #creo il dataframe
        df = pd.DataFrame({
                "TIME_NS": time_ns,
                "TIME_S": time_s,
                "TIME_ABS": time_abs,
                "EVENT": event,
                "MCRUN": mcrun,
                "TEL_ID": i,
                "HG": list(hg),             
                "LG": list(lg),
                "TTP": list(ttp)
            })

        dfs.append(df)
df_all = pd.concat(dfs, ignore_index=True)
df_all_sorted= df_all.sort_values(by="TIME_ABS").reset_index(drop=True)
print(df_all.head())
print(df_all_sorted.head())
# Out:
# astri_001_43_009_00002_R_201023_004_0201_SEB.lv0
# astri_002_43_009_00002_R_201023_004_0201_SEB.lv0
# astri_003_43_009_00002_R_201023_004_0201_SEB.lv0
# astri_004_43_009_00002_R_201023_004_0201_SEB.lv0
# astri_005_43_009_00002_R_201023_004_0201_SEB.lv0
# astri_006_43_009_00002_R_201023_004_0201_SEB.lv0
# astri_007_43_009_00002_R_201023_004_0201_SEB.lv0
# astri_008_43_009_00002_R_201023_004_0201_SEB.lv0
# astri_009_43_009_00002_R_201023_004_0201_SEB.lv0
#     TIME_NS  TIME_S  TIME_ABS  EVENT   MCRUN  TEL_ID  \
# 0  15104575       0  15104575   2217  263211       1
# 1  25307129       0  25307129   7009  263211       1
# 2  28859186       0  28859186   2217  263212       1
# 3  32680807       0  32680807   4213  263212       1
# 4  35023796       0  35023796    417  263213       1
#
#                                                   HG  \
# 0  [[2158, 2264, 2118, 2251, 2150, 2144, 2247, 22...
# 1  [[2251, 2145, 2137, 2122, 2236, 2138, 2146, 22...
# ...

# %%
df_target= df_all_sorted[
    ((df_all_sorted['EVENT'] == 3109 ) | (df_all_sorted['EVENT'] == 9705 )) &
    ((df_all_sorted['MCRUN'] == 266033) | (df_all_sorted['MCRUN'] == 263369) )
]
print(df_target[["TIME_NS", "TIME_S","TIME_ABS"]])
# Out:
#          TIME_NS  TIME_S    TIME_ABS
# 4462   599190677       1  1599190677
# 4463   599190850       1  1599190850
# 4464   599190978       1  1599190978
# 4465   599191074       1  1599191074
# 4466   599191383       1  1599191383
# 4467   599191442       1  1599191442
# 4468   599191467       1  1599191467
# 4469   599191880       1  1599191880
# 4470   599191911       1  1599191911
# 14810  466290070       5  5466290070
# 14811  466290239       5  5466290239
# 14812  466290420       5  5466290420
# 14813  466290499       5  5466290499
# 14814  466290869       5  5466290869
# 14815  466290902       5  5466290902
# 14816  466290908       5  5466290908
# 14817  466291393       5  5466291393
# 14818  466291410       5  5466291410

# %%
import scipy.stats as sc


xfp, yfp = at.utils.camera.get_xy_footprint() 
y_pix, x_pix = at.utils.camera.get_pixels_position_matrix().T

x_pix = at.reshape(x_pix)
y_pix = at.reshape(y_pix)

# ============================================================
# SELEZIONE TELESCOPI: CONTROLLO MANUALE per ogni evento
# ============================================================

unique_events = df_target["EVENT"].unique()
print(f"Eventi presenti: {unique_events}")

# Prima mostriamo tutti i telescopi disponibili per ogni evento
print("\n=== TELESCOPI DISPONIBILI PER EVENTO ===")
telescopes_by_event = {}
for event in unique_events:
    event_mask = df_target["EVENT"] == event
    telescopes_by_event[event] = sorted(df_target[event_mask]["TEL_ID"].unique().tolist())
    print(f"Evento {event}: {telescopes_by_event[event]}")

# ============================================================
# 🔧 CONFIGURAZIONE MANUALE - MODIFICA QUI I TELESCOPI
# ============================================================
# Inserisci qui quali telescopi vuoi per ogni evento
# Esempio: 
selected_telescopes_by_event = {3109: [1, 3, 6, 8], 9705: [2, 4, 5, 7, 9]}

#selected_telescopes_by_event = {unique_events[0]: telescopes_by_event[unique_events[0]][:4],  # primi 4 per evento 0unique_events[1]: telescopes_by_event[unique_events[1]][:5]   # primi 5 per evento 1
#}

# OPPURE specifica manualmente (esempio commentato):
# selected_telescopes_by_event = {
#     unique_events[0]: [1, 3, 5, 7],      # telescopi specifici per evento 0
#     unique_events[1]: [2, 4, 6, 8, 9]    # telescopi specifici per evento 1
# }
# ============================================================

print("\n=== TELESCOPI SELEZIONATI ===")
for event in unique_events:
    print(f"Evento {event}: {selected_telescopes_by_event[event]}")

# Verifica che i telescopi selezionati esistano
for event in unique_events:
    for tel in selected_telescopes_by_event[event]:
        if tel not in telescopes_by_event[event]:
            print(f"⚠️  ATTENZIONE: Telescopio {tel} non disponibile per evento {event}!")

# Verifica overlap tra eventi
events_list = list(unique_events)
if len(events_list) >= 2:
    set_event_0 = set(selected_telescopes_by_event[events_list[0]])
    set_event_1 = set(selected_telescopes_by_event[events_list[1]])
    overlap = set_event_0.intersection(set_event_1)
    print(f"\n✓ Verifica overlap: {len(overlap)} telescopi in comune")
    if overlap:
        print(f"  ⚠️  ATTENZIONE: Telescopi condivisi tra eventi: {overlap}")
    else:
        print(f"  ✓ Perfetto! Nessun telescopio condiviso tra eventi")

# Crea gli indici selezionati
selected_indices = []
all_used_telescopes = set()

for event in unique_events:
    for tel in selected_telescopes_by_event[event]:
        tel_mask = (df_target["EVENT"] == event) & (df_target["TEL_ID"] == tel)
        matching_indices = df_target[tel_mask].index.tolist()
        if matching_indices:
            selected_indices.append(matching_indices[0])
            all_used_telescopes.add(tel)

print(f"\nTotale telescopi selezionati: {len(selected_indices)}")
print(f"Telescopi unici usati: {len(all_used_telescopes)}")
print(f"Verifica: tutti diversi? {len(all_used_telescopes) == len(selected_indices)}")

# Crea dataframe filtrato
df_target = df_target.loc[selected_indices].copy()

print(f"\nRighe in df_target: {len(df_target)}")
print(f"Telescopi unici: {df_target['TEL_ID'].nunique()}")
print(f"TEL_ID presenti: {sorted(df_target['TEL_ID'].unique())}")

# ============================================================
# Calcolo rette sui telescopi selezionati
# ============================================================

color_list = ["royalblue", "orange"]
color_map = {ev: color_list[i % len(color_list)] for i, ev in enumerate(unique_events)}

rette_hg = []
weights_hg_sum = np.zeros_like(np.array(df_target['HG'].iloc[0]))
mask_tot = np.zeros((37, 64), dtype=bool)

for iv in range(len(df_target)):

    itel = df_target["TEL_ID"].iloc[iv]
    event = df_target["EVENT"].iloc[iv]
    hgev = np.array(df_target['HG'].iloc[iv])
    lgev = np.array(df_target['LG'].iloc[iv])
    ttpev = np.array(df_target['TTP'].iloc[iv])

    # mask di pixel buoni
    pxmask = (hgev > 2400) & (ttpev < 255)

    # Accumulo per heatmap
    weights_hg_sum[pxmask] += hgev[pxmask]
    mask_tot |= pxmask

    # SIGMA-CLIPPING
    xx = x_pix[pxmask].flatten()
    yy = y_pix[pxmask].flatten()
    w_hg = hgev[pxmask].flatten()

    if len(xx) == 0:
        print(f"  Warning: Telescopio {itel} (evento {event}) - nessun pixel valido")
        continue

    mx0 = np.average(xx, weights=w_hg)
    my0 = np.average(yy, weights=w_hg)

    r = np.sqrt((xx - mx0)**2 + (yy - my0)**2)

    r_clip, low, high = sc.sigmaclip(r, low=3.0, high=3.0)
    keep = (r >= low) & (r <= high)

    xx_sc = xx[keep]
    yy_sc = yy[keep]
    w_hg_sc = w_hg[keep]

    if len(xx_sc) == 0:
        print(f"  Warning: Telescopio {itel} (evento {event}) - nessun pixel dopo sigma clipping")
        continue

    # centroidi
    meanx_hg = np.average(xx_sc, weights=w_hg_sc)
    meany_hg = np.average(yy_sc, weights=w_hg_sc)

    # covarianze
    cov_hg = np.cov([xx_sc, yy_sc], aweights=w_hg_sc)

    # parametri ellisse
    trace = cov_hg[0, 0] + cov_hg[1, 1]
    det_diff = ((cov_hg[0, 0] - cov_hg[1, 1]) / 2) ** 2 + cov_hg[0, 1] ** 2
    sqrt_det = np.sqrt(det_diff)
    
    l1_hg = trace / 2 + sqrt_det
    l2_hg = trace / 2 - sqrt_det
    theta_hg = np.arctan2(l1_hg - cov_hg[0, 0], cov_hg[0, 1])

    # salvo le rette
    rette_hg.append({
        "p0": np.array([meanx_hg, meany_hg]),
        "d":  np.array([np.cos(theta_hg), np.sin(theta_hg)]),
        "l1": l1_hg,
        "l2": l2_hg,
        "theta": theta_hg,
        "tel": itel,
        "event": event
    })

print(f"\nRette HG calcolate: {len(rette_hg)}")

# ============================================================
# Plot HG: heatmap + rette colorate per evento
# ============================================================

fig, ax = plt.subplots(figsize=(10, 10))

# Heatmap HG
weights_hg_sum = np.array(weights_hg_sum)
h = ax.hist2d(
    x_pix[mask_tot].flatten(), 
    y_pix[mask_tot].flatten(),
    weights=weights_hg_sum[mask_tot].flatten(), 
    range=((-205, 205), (-205, 205)),
    bins=7*8, 
    cmap='Greens',
    alpha=0.7
)

# Footprint camera 
ax.plot(xfp, yfp, 'k-', linewidth=1.5, zorder=2)

# Lunghezza rette
xmin, xmax = np.min(xfp), np.max(xfp)
ymin, ymax = np.min(yfp), np.max(yfp)
diag = np.sqrt((xmax - xmin)**2 + (ymax - ymin)**2)
L = 0.40 * diag

# Rette e centroidi colorati per evento
for r in rette_hg:
    p0 = r["p0"]
    d  = r["d"]
    col = color_map[r["event"]]
    
    # Retta
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color=col, linewidth=2.5, alpha=0.85, zorder=4)
    
    # Centroide
    ax.scatter(p0[0], p0[1], s=100, color=col, edgecolor="white", linewidth=2, zorder=5)

ax.set_title(f"HG - {len(rette_hg)} rette (max 9 telescopi UNICI)", 
             fontsize=15, pad=12, fontweight='bold')
ax.set_xlim(-205, 205)
ax.set_ylim(-205, 205)
ax.set_aspect('equal')
ax.set_xlabel('x [mm]', fontsize=13)
ax.set_ylabel('y [mm]', fontsize=13)
ax.grid(True, linestyle=':', alpha=0.3)

# Legenda
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor=color_map[ev], 
          label=f'Evento {ev} ({sum(1 for r in rette_hg if r["event"] == ev)} tel)') 
    for ev in unique_events
]
ax.legend(handles=legend_elements, loc='upper right', fontsize=12, framealpha=0.95)

cbar = fig.colorbar(h[3], ax=ax, label='Segnale HG somma', pad=0.02)
cbar.ax.tick_params(labelsize=11)

plt.tight_layout()
plt.show()

print(f"\nRiepilogo:")
print(f"  Evento {unique_events[0]}: {sum(1 for r in rette_hg if r['event'] == unique_events[0])} rette")
print(f"  Evento {unique_events[1]}: {sum(1 for r in rette_hg if r['event'] == unique_events[1])} rette")
print(f"  Telescopi totali unici: {len(set(r['tel'] for r in rette_hg))}")

# ============================================================
# ESPORTA df_target per analisi successive
# ============================================================
print(f"\n✓ Usa 'df_target' per tutte le analisi successive!")
print(f"✓ Contiene {len(df_target)} righe con {df_target['TEL_ID'].nunique()} telescopi UNICI.")
# Out:
# Eventi presenti: [9705 3109]
#
# === TELESCOPI DISPONIBILI PER EVENTO ===
# Evento 9705: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Evento 3109: [1, 2, 3, 4, 5, 6, 7, 8, 9]
#
# === TELESCOPI SELEZIONATI ===
# Evento 9705: [2, 4, 5, 7, 9]
# Evento 3109: [1, 3, 6, 8]
#
# ✓ Verifica overlap: 0 telescopi in comune
#   ✓ Perfetto! Nessun telescopio condiviso tra eventi
#
# Totale telescopi selezionati: 9
# Telescopi unici usati: 9
# Verifica: tutti diversi? True
#
# Righe in df_target: 9
# Telescopi unici: 9
# TEL_ID presenti: [1, 2, 3, 4, 5, 6, 7, 8, 9]
#
# Rette HG calcolate: 9
# Riepilogo:
#   Evento 9705: 5 rette
#   Evento 3109: 4 rette
#   Telescopi totali unici: 9
#
# ✓ Usa 'df_target' per tutte le analisi successive!
# ✓ Contiene 9 righe con 9 telescopi UNICI.

# %%
xfp, yfp = at.utils.camera.get_xy_footprint()
y_pix, x_pix = at.utils.camera.get_pixels_position_matrix().T

x_pix = at.reshape(x_pix)
y_pix = at.reshape(y_pix)

rette_hg = []
rette_lg = []

# ============================================================
#   calcolo, sigma clip, istogrammi, salvataggio rette

for iv in range(len(df_target)):

    itel = df_target["TEL_ID"].iloc[iv]
    hgev = np.array(df_target['HG'])[iv]
    lgev = np.array(df_target['LG'])[iv]
    ttpev = np.array(df_target['TTP'])[iv]

    # mask di pixel buoni
    pxmask = (hgev > 2400) & (ttpev < 255)

    # --------------------------
    # SIGMA-CLIPPING
    
    xx = x_pix[pxmask].flatten()
    yy = y_pix[pxmask].flatten()
    w_hg = hgev[pxmask].flatten()
    w_lg = lgev[pxmask].flatten()

    mx0 = np.average(xx, weights=w_hg)
    my0 = np.average(yy, weights=w_hg)

    r = np.sqrt((xx - mx0)**2 + (yy - my0)**2)

    r_clip, low, high = sc.sigmaclip(r, low=3.0, high=3.0)
    keep = (r >= low) & (r <= high)

    xx_sc = xx[keep]
    yy_sc = yy[keep]
    w_hg_sc = w_hg[keep]
    w_lg_sc = w_lg[keep]
    # --------------------------

    # ---------- centroidi ----------
    meanx_hg = np.average(xx_sc, weights=w_hg_sc)
    meany_hg = np.average(yy_sc, weights=w_hg_sc)

    meanx_lg = np.average(xx_sc, weights=w_lg_sc)
    meany_lg = np.average(yy_sc, weights=w_lg_sc)

    # ---------- covarianze ----------
    cov_hg = np.cov([xx_sc, yy_sc], aweights=w_hg_sc)
    cov_lg = np.cov([xx_sc, yy_sc], aweights=w_lg_sc)

    # ---------- direzione ellisse ----------
    l1_hg = (cov_hg[0,0] + cov_hg[1,1])/2 + np.sqrt(((cov_hg[0,0]-cov_hg[1,1])/2)**2 + cov_hg[0,1]**2)
    l1_lg = (cov_lg[0,0] + cov_lg[1,1])/2 + np.sqrt(((cov_lg[0,0]-cov_lg[1,1])/2)**2 + cov_lg[0,1]**2)

    theta_hg = np.arctan2(l1_hg - cov_hg[0,0], cov_hg[0,1])
    theta_lg = np.arctan2(l1_lg - cov_lg[0,0], cov_lg[0,1])

    # ---------- salvo le rette ----------
    rette_hg.append({
        "p0": np.array([meanx_hg, meany_hg]),
        "d":  np.array([np.cos(theta_hg), np.sin(theta_hg)]),
        "tel": itel
    })

    rette_lg.append({
        "p0": np.array([meanx_lg, meany_lg]),
        "d":  np.array([np.cos(theta_lg), np.sin(theta_lg)]),
        "tel": itel
    })
# ============================================================
#   tutte le rette insieme

fig, ax = plt.subplots(figsize=(6, 6))
# footprint camera 
ax.plot(xfp, yfp, 'k-', linewidth=1)

# calcolo lunghezza estetica delle rette
xmin, xmax = np.min(xfp), np.max(xfp)
ymin, ymax = np.min(yfp), np.max(yfp)
diag = np.sqrt((xmax - xmin)**2 + (ymax - ymin)**2)
L = 0.40 * diag

# centroidi e rette HG
for r in rette_hg:
    p0 = r["p0"]
    d  = r["d"]

    # centroide HG (punto rosso grande)
    ax.scatter(p0[0], p0[1], s=80, color="firebrick", zorder=5)

    # retta lunga HG (firebrick)
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color="firebrick", linewidth=2, alpha=0.8)

#  centroidi e rette LG 
for r in rette_lg:
    p0 = r["p0"]
    d  = r["d"]

    # centroide LG (punto grigio più piccolo con bordo nero)
    ax.scatter(p0[0], p0[1], s=60, color="grey", edgecolor="black", zorder=5)

    # retta lunga LG (grey)
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color="grey", linewidth=2, alpha=0.8)

ax.set_title("rette  due eventi")
ax.set_xlim(-250,250 )
ax.set_ylim(-250,250)

plt.tight_layout()
plt.show()

print("HG rette:", len(rette_hg))
print("LG rette:", len(rette_lg))
print(rette_hg[0])
# Out:
# HG rette: 9
# LG rette: 9
# {'p0': array([22.99149501, 86.22200894]), 'd': array([-0.48662229,  0.87361247]), 'tel': 2}

# %%
def intersection(p1, d1, p2, d2):
    """
    p1, p2 = centroidi
    d1, d2 = direzioni 
    """
    A = np.array([d1, -d2]).T
    b = p2 - p1

    # determinante per capire se sono parallele
    det = np.linalg.det(A)
    if abs(det) < 1e-6:
        return None  
    # risolvi i parametri t
    t = np.linalg.solve(A, b)[0]

    # punto di intersezione
    return p1 + t * d1
# ####################################################
# INTERSEZIONI TRA TUTTE LE COPPIE DI RETTE HG
# ####################################################
N = len(rette_hg)
inters_hg = []

for i in range(N):
    p1 = rette_hg[i]["p0"]
    d1 = rette_hg[i]["d"]
    for j in range(i+1, N):
        p2 = rette_hg[j]["p0"]
        d2 = rette_hg[j]["d"]
        P = intersection(p1, d1, p2, d2)
        if P is not None:
            inters_hg.append(P)

inters_hg = np.array(inters_hg)
v_hg_nf = inters_hg.copy()   


# #####################################################
# INTERSEZIONI TRA TUTTE LE COPPIE DI RETTE LG
# ####################################################à
N = len(rette_lg)
inters_lg = []

for i in range(N):
    p1 = rette_lg[i]["p0"]
    d1 = rette_lg[i]["d"]
    for j in range(i+1, N):
        p2 = rette_lg[j]["p0"]
        d2 = rette_lg[j]["d"]
        P = intersection(p1, d1, p2, d2)
        if P is not None:
            inters_lg.append(P)

inters_lg = np.array(inters_lg)
v_lg_nf = inters_lg.copy()  
#####Filtro i punti troppo lontani (grezzo)###############################################
v_hg= np.array([p for p in v_hg_nf if  all(-1000 <= coord <= 1000 for coord in p)])
v_lg= np.array([p for p in v_lg_nf if  all(-1000 <= coord <= 1000 for coord in p)])

# %%
xfp, yfp = at.utils.camera.get_xy_footprint() 
y_pix, x_pix = at.utils.camera.get_pixels_position_matrix().T

x_pix = at.reshape(x_pix)
y_pix = at.reshape(y_pix)

rette_hg = []
rette_lg = []

# ============================================================
#   calcolo, sigma clip, salvataggio rette con EVENT

# estrai eventi unici e crea mappa colori
unique_events = df_target["EVENT"].unique()
color_list = ["tab:red", "tab:blue"]
color_map = {ev: color_list[i % len(color_list)] for i, ev in enumerate(unique_events)}

for iv in range(len(df_target)):

    itel = df_target["TEL_ID"].iloc[iv]
    event = df_target["EVENT"].iloc[iv]  # prendo l'evento
    hgev = np.array(df_target['HG'])[iv]
    lgev = np.array(df_target['LG'])[iv]
    ttpev = np.array(df_target['TTP'])[iv]

    # mask di pixel buoni
    pxmask = (hgev > 2400) & (ttpev < 255)

    # --------------------------
    # SIGMA-CLIPPING
    xx = x_pix[pxmask].flatten()
    yy = y_pix[pxmask].flatten()
    w_hg = hgev[pxmask].flatten()
    w_lg = lgev[pxmask].flatten()

    mx0 = np.average(xx, weights=w_hg)
    my0 = np.average(yy, weights=w_hg)

    r = np.sqrt((xx - mx0)**2 + (yy - my0)**2)

    r_clip, low, high = sc.sigmaclip(r, low=3.0, high=3.0)
    keep = (r >= low) & (r <= high)

    xx_sc = xx[keep]
    yy_sc = yy[keep]
    w_hg_sc = w_hg[keep]
    w_lg_sc = w_lg[keep]


    # ---------- centroidi ----------
    meanx_hg = np.average(xx_sc, weights=w_hg_sc)
    meany_hg = np.average(yy_sc, weights=w_hg_sc)

    meanx_lg = np.average(xx_sc, weights=w_lg_sc)
    meany_lg = np.average(yy_sc, weights=w_lg_sc)

    # ---------- covarianze ----------
    cov_hg = np.cov([xx_sc, yy_sc], aweights=w_hg_sc)
    cov_lg = np.cov([xx_sc, yy_sc], aweights=w_lg_sc)

    # ---------- direzione ellisse ----------
    l1_hg = (cov_hg[0,0] + cov_hg[1,1])/2 + np.sqrt(((cov_hg[0,0]-cov_hg[1,1])/2)**2 + cov_hg[0,1]**2)
    l1_lg = (cov_lg[0,0] + cov_lg[1,1])/2 + np.sqrt(((cov_lg[0,0]-cov_lg[1,1])/2)**2 + cov_lg[0,1]**2)

    theta_hg = np.arctan2(l1_hg - cov_hg[0,0], cov_hg[0,1])
    theta_lg = np.arctan2(l1_lg - cov_lg[0,0], cov_lg[0,1])

    # ---------- salvo le rette ----------
    rette_hg.append({
        "p0": np.array([meanx_hg, meany_hg]),
        "d":  np.array([np.cos(theta_hg), np.sin(theta_hg)]),
        "tel": itel,
        "event": event  # salvo l'evento
    })

    rette_lg.append({
        "p0": np.array([meanx_lg, meany_lg]),
        "d":  np.array([np.cos(theta_lg), np.sin(theta_lg)]),
        "tel": itel,
        "event": event  # salvo l'evento
    })
# ============================================================
#   tutte le rette insieme colorate per EVENT

fig, ax = plt.subplots(figsize=(6, 6))
# footprint camera 
ax.plot(xfp, yfp, 'k-', linewidth=1)

# calcolo lunghezza estetica delle rette
xmin, xmax = np.min(xfp), np.max(xfp)
ymin, ymax = np.min(yfp), np.max(yfp)
diag = np.sqrt((xmax - xmin)**2 + (ymax - ymin)**2)
L = 0.40 * diag

# centroidi e rette HG
for r in rette_hg:
    p0 = r["p0"]
    d  = r["d"]
    ev = r["event"]
    col = color_map[ev]

    # centroide HG
    ax.scatter(p0[0], p0[1], s=80, color=col, edgecolor="black", zorder=5)
    # retta lunga HG
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color=col, linewidth=2, alpha=0.8)

#  centroidi e rette LG 
for r in rette_lg:
    p0 = r["p0"]
    d  = r["d"]
    ev = r["event"]
    col = color_map[ev]

    # centroide LG
    ax.scatter(p0[0], p0[1], s=60, color=col, edgecolor="black", zorder=5)
    # retta lunga LG
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color=col, linewidth=1.8, alpha=0.8)

ax.set_title("Rette colorate per EVENT")
ax.set_xlim(-250, 250)
ax.set_ylim(-250, 250)

plt.tight_layout()
plt.show()

print("HG rette:", len(rette_hg))
print("LG rette:", len(rette_lg))
print(rette_hg[0])
# Out:
# HG rette: 9
# LG rette: 9
# {'p0': array([22.99149501, 86.22200894]), 'd': array([-0.48662229,  0.87361247]), 'tel': 2, 'event': 9705}

# %%
from matplotlib.colors import PowerNorm
from matplotlib.colors import LogNorm

xfp, yfp = at.utils.camera.get_xy_footprint() 
y_pix, x_pix = at.utils.camera.get_pixels_position_matrix().T

x_pix = at.reshape(x_pix)
y_pix = at.reshape(y_pix)

rette_hg = []
rette_lg = []

# ============================================================
#   calcolo, sigma clip, salvataggio rette con EVENT

# estrai eventi unici e crea mappa colori
unique_events = df_target["EVENT"].unique()
color_list = ["tab:red", "tab:blue"]
color_map = {ev: color_list[i % len(color_list)] for i, ev in enumerate(unique_events)}

# Accumulatori separati per evento
weights_hg_per_event = {ev: np.zeros_like(np.array(df_target['HG'])[0]) for ev in unique_events}
weights_lg_per_event = {ev: np.zeros_like(np.array(df_target['LG'])[0]) for ev in unique_events}
mask_per_event = {ev: np.zeros((37, 64), dtype=bool) for ev in unique_events}

for iv in range(len(df_target)):

    itel = df_target["TEL_ID"].iloc[iv]
    event = df_target["EVENT"].iloc[iv]  # prendo l'evento
    hgev = np.array(df_target['HG'])[iv]
    lgev = np.array(df_target['LG'])[iv]
    ttpev = np.array(df_target['TTP'])[iv]

    # mask di pixel buoni
    pxmask = (hgev > 2400) & (ttpev < 255)

    # Accumulo per heatmap SOLO per questo evento
    weights_hg_per_event[event][pxmask] += hgev[pxmask]
    weights_lg_per_event[event][pxmask] += lgev[pxmask]
    mask_per_event[event] |= pxmask

    # --------------------------
    # SIGMA-CLIPPING
    xx = x_pix[pxmask].flatten()
    yy = y_pix[pxmask].flatten()
    w_hg = hgev[pxmask].flatten()
    w_lg = lgev[pxmask].flatten()

    if len(xx) == 0:
        continue

    mx0 = np.average(xx, weights=w_hg)
    my0 = np.average(yy, weights=w_hg)

    r = np.sqrt((xx - mx0)**2 + (yy - my0)**2)

    r_clip, low, high = sc.sigmaclip(r, low=3.0, high=3.0)
    keep = (r >= low) & (r <= high)

    xx_sc = xx[keep]
    yy_sc = yy[keep]
    w_hg_sc = w_hg[keep]
    w_lg_sc = w_lg[keep]

    if len(xx_sc) == 0:
        continue

    # ---------- centroidi ----------
    meanx_hg = np.average(xx_sc, weights=w_hg_sc)
    meany_hg = np.average(yy_sc, weights=w_hg_sc)

    meanx_lg = np.average(xx_sc, weights=w_lg_sc)
    meany_lg = np.average(yy_sc, weights=w_lg_sc)

    # ---------- covarianze ----------
    cov_hg = np.cov([xx_sc, yy_sc], aweights=w_hg_sc)
    cov_lg = np.cov([xx_sc, yy_sc], aweights=w_lg_sc)

    # ---------- direzione ellisse ----------
    l1_hg = (cov_hg[0,0] + cov_hg[1,1])/2 + np.sqrt(((cov_hg[0,0]-cov_hg[1,1])/2)**2 + cov_hg[0,1]**2)
    l1_lg = (cov_lg[0,0] + cov_lg[1,1])/2 + np.sqrt(((cov_lg[0,0]-cov_lg[1,1])/2)**2 + cov_lg[0,1]**2)

    theta_hg = np.arctan2(l1_hg - cov_hg[0,0], cov_hg[0,1])
    theta_lg = np.arctan2(l1_lg - cov_lg[0,0], cov_lg[0,1])

    # ---------- salvo le rette ----------
    rette_hg.append({
        "p0": np.array([meanx_hg, meany_hg]),
        "d":  np.array([np.cos(theta_hg), np.sin(theta_hg)]),
        "tel": itel,
        "event": event  # salvo l'evento
    })

    rette_lg.append({
        "p0": np.array([meanx_lg, meany_lg]),
        "d":  np.array([np.cos(theta_lg), np.sin(theta_lg)]),
        "tel": itel,
        "event": event  # salvo l'evento
    })

# Calcolo lunghezza estetica delle rette
xmin, xmax = np.min(xfp), np.max(xfp)
ymin, ymax = np.min(yfp), np.max(yfp)
diag = np.sqrt((xmax - xmin)**2 + (ymax - ymin)**2)
L = 0.40 * diag

# ============================================================
#   Plot separato per ogni evento (HG)

for event in unique_events:
    fig, ax = plt.subplots(figsize=(12, 10))
    
    # Heatmap HG per questo evento
    weights_hg = np.array(weights_hg_per_event[event])
    mask_ev = mask_per_event[event]
    
    if np.sum(mask_ev) > 0:
        h = ax.hist2d(
            x_pix[mask_ev].flatten(), 
            y_pix[mask_ev].flatten(),
            weights=weights_hg[mask_ev].flatten(), 
            range=((-205, 205), (-205, 205)),
            bins=7*8, 
            norm=PowerNorm(gamma=0.3),
            cmap='Greens'
        )
        cbar = fig.colorbar(h[3], ax=ax, label='Segnale HG somma')
    
    # Footprint camera 
    ax.plot(xfp, yfp, 'k-', linewidth=1.5, zorder=2)
    
    # Solo rette di questo evento
    col = color_map[event]
    for r in rette_hg:
        if r["event"] != event:
            continue
        
        p0 = r["p0"]
        d  = r["d"]
        
        # centroide HG
        ax.scatter(p0[0], p0[1], s=100, color=col, edgecolor="white", linewidth=1.5, zorder=5)
        # retta lunga HG
        x1 = p0[0] - L * d[0]
        y1 = p0[1] - L * d[1]
        x2 = p0[0] + L * d[0]
        y2 = p0[1] + L * d[1]
        ax.plot([x1, x2], [y1, y2], color=col, linewidth=2.5, alpha=0.9, zorder=4)
    
    ax.set_title(f"HG - EVENT {event}", fontsize=14, pad=10)
    ax.set_xlim(-205, 205)
    ax.set_ylim(-205, 205)
    ax.set_aspect('equal')
    ax.set_xlabel('x [mm]')
    ax.set_ylabel('y [mm]')
    
    plt.tight_layout()
    plt.show()

# ============================================================
#   Plot separato per ogni evento (LG)

for event in unique_events:
    fig, ax = plt.subplots(figsize=(10, 10))
    
    # Heatmap LG per questo evento
    weights_lg = np.array(weights_lg_per_event[event])
    mask_ev = mask_per_event[event]
    
    if np.sum(mask_ev) > 0:
        h = ax.hist2d(
            x_pix[mask_ev].flatten(), 
            y_pix[mask_ev].flatten(),
            weights=weights_lg[mask_ev].flatten(), 
            range=((-205, 205), (-205, 205)),
            bins=7*8, 
            cmap='Blues'
        )
        cbar = fig.colorbar(h[3], ax=ax, label='Segnale LG somma')
    
    # Footprint camera 
    ax.plot(xfp, yfp, 'k-', linewidth=1.5, zorder=2)
    
    # Solo rette di questo evento
    col = color_map[event]
    for r in rette_lg:
        if r["event"] != event:
            continue
        
        p0 = r["p0"]
        d  = r["d"]
        
        # centroide LG
        ax.scatter(p0[0], p0[1], s=80, color=col, edgecolor="white", linewidth=1.5, zorder=5)
        # retta lunga LG
        x1 = p0[0] - L * d[0]
        y1 = p0[1] - L * d[1]
        x2 = p0[0] + L * d[0]
        y2 = p0[1] + L * d[1]
        ax.plot([x1, x2], [y1, y2], color=col, linewidth=2.5, alpha=0.9, zorder=4)
    
    ax.set_title(f"LG - EVENT {event}", fontsize=14, pad=10)
    ax.set_xlim(-205, 205)
    ax.set_ylim(-205, 205)
    ax.set_aspect('equal')
    ax.set_xlabel('x [mm]')
    ax.set_ylabel('y [mm]')
    
    plt.tight_layout()
    plt.show()

print("HG rette:", len(rette_hg))
print("LG rette:", len(rette_lg))
# Out:
# HG rette: 9
# LG rette: 9

# %%
sc


xfp, yfp = at.utils.camera.get_xy_footprint() 
y_pix, x_pix = at.utils.camera.get_pixels_position_matrix().T

x_pix = at.reshape(x_pix)
y_pix = at.reshape(y_pix)

# ============================================================
# SELEZIONE TELESCOPI: CONTROLLO MANUALE per ogni evento
# ============================================================

unique_events = df_target["EVENT"].unique()
print(f"Eventi presenti: {unique_events}")

# Prima mostriamo tutti i telescopi disponibili per ogni evento
print("\n=== TELESCOPI DISPONIBILI PER EVENTO ===")
telescopes_by_event = {}
for event in unique_events:
    event_mask = df_target["EVENT"] == event
    telescopes_by_event[event] = sorted(df_target[event_mask]["TEL_ID"].unique().tolist())
    print(f"Evento {event}: {telescopes_by_event[event]}")

# ============================================================
# 🔧 CONFIGURAZIONE MANUALE - MODIFICA QUI I TELESCOPI
# ============================================================
# Inserisci qui quali telescopi vuoi per ogni evento
# Esempio: 
selected_telescopes_by_event = {3109: [1, 3, 6, 8], 9705: [2, 4, 5, 7, 9]}

#selected_telescopes_by_event = {unique_events[0]: telescopes_by_event[unique_events[0]][:4],  # primi 4 per evento 0unique_events[1]: telescopes_by_event[unique_events[1]][:5]   # primi 5 per evento 1
#}

# OPPURE specifica manualmente (esempio commentato):
# selected_telescopes_by_event = {
#     unique_events[0]: [1, 3, 5, 7],      # telescopi specifici per evento 0
#     unique_events[1]: [2, 4, 6, 8, 9]    # telescopi specifici per evento 1
# }
# ============================================================

print("\n=== TELESCOPI SELEZIONATI ===")
for event in unique_events:
    print(f"Evento {event}: {selected_telescopes_by_event[event]}")

# Verifica che i telescopi selezionati esistano
for event in unique_events:
    for tel in selected_telescopes_by_event[event]:
        if tel not in telescopes_by_event[event]:
            print(f"⚠️  ATTENZIONE: Telescopio {tel} non disponibile per evento {event}!")

# Verifica overlap tra eventi
events_list = list(unique_events)
if len(events_list) >= 2:
    set_event_0 = set(selected_telescopes_by_event[events_list[0]])
    set_event_1 = set(selected_telescopes_by_event[events_list[1]])
    overlap = set_event_0.intersection(set_event_1)
    print(f"\n✓ Verifica overlap: {len(overlap)} telescopi in comune")
    if overlap:
        print(f"  ⚠️  ATTENZIONE: Telescopi condivisi tra eventi: {overlap}")
    else:
        print(f"  ✓ Perfetto! Nessun telescopio condiviso tra eventi")

# Crea gli indici selezionati
selected_indices = []
all_used_telescopes = set()

for event in unique_events:
    for tel in selected_telescopes_by_event[event]:
        tel_mask = (df_target["EVENT"] == event) & (df_target["TEL_ID"] == tel)
        matching_indices = df_target[tel_mask].index.tolist()
        if matching_indices:
            selected_indices.append(matching_indices[0])
            all_used_telescopes.add(tel)

print(f"\nTotale telescopi selezionati: {len(selected_indices)}")
print(f"Telescopi unici usati: {len(all_used_telescopes)}")
print(f"Verifica: tutti diversi? {len(all_used_telescopes) == len(selected_indices)}")

# Crea dataframe filtrato
df_target_filtered = df_target.loc[selected_indices].copy()

print(f"\nRighe in df_target_filtered: {len(df_target_filtered)}")
print(f"Telescopi unici: {df_target_filtered['TEL_ID'].nunique()}")
print(f"TEL_ID presenti: {sorted(df_target_filtered['TEL_ID'].unique())}")

# ============================================================
# Calcolo rette sui telescopi selezionati
# ============================================================

color_list = ["royalblue", "orange"]
color_map = {ev: color_list[i % len(color_list)] for i, ev in enumerate(unique_events)}

rette_hg = []
weights_hg_sum = np.zeros_like(np.array(df_target_filtered['HG'].iloc[0]))
mask_tot = np.zeros((37, 64), dtype=bool)

for iv in range(len(df_target_filtered)):

    itel = df_target_filtered["TEL_ID"].iloc[iv]
    event = df_target_filtered["EVENT"].iloc[iv]
    hgev = np.array(df_target_filtered['HG'].iloc[iv])
    lgev = np.array(df_target_filtered['LG'].iloc[iv])
    ttpev = np.array(df_target_filtered['TTP'].iloc[iv])

    # mask di pixel buoni
    pxmask = (hgev > 2400) & (ttpev < 255)

    # Accumulo per heatmap
    weights_hg_sum[pxmask] += hgev[pxmask]
    mask_tot |= pxmask

    # SIGMA-CLIPPING
    xx = x_pix[pxmask].flatten()
    yy = y_pix[pxmask].flatten()
    w_hg = hgev[pxmask].flatten()

    if len(xx) == 0:
        print(f"  Warning: Telescopio {itel} (evento {event}) - nessun pixel valido")
        continue

    mx0 = np.average(xx, weights=w_hg)
    my0 = np.average(yy, weights=w_hg)

    r = np.sqrt((xx - mx0)**2 + (yy - my0)**2)

    r_clip, low, high = sc.sigmaclip(r, low=3.0, high=3.0)
    keep = (r >= low) & (r <= high)

    xx_sc = xx[keep]
    yy_sc = yy[keep]
    w_hg_sc = w_hg[keep]

    if len(xx_sc) == 0:
        print(f"  Warning: Telescopio {itel} (evento {event}) - nessun pixel dopo sigma clipping")
        continue

    # centroidi
    meanx_hg = np.average(xx_sc, weights=w_hg_sc)
    meany_hg = np.average(yy_sc, weights=w_hg_sc)

    # covarianze
    cov_hg = np.cov([xx_sc, yy_sc], aweights=w_hg_sc)

    # parametri ellisse
    trace = cov_hg[0, 0] + cov_hg[1, 1]
    det_diff = ((cov_hg[0, 0] - cov_hg[1, 1]) / 2) ** 2 + cov_hg[0, 1] ** 2
    sqrt_det = np.sqrt(det_diff)
    
    l1_hg = trace / 2 + sqrt_det
    l2_hg = trace / 2 - sqrt_det
    theta_hg = np.arctan2(l1_hg - cov_hg[0, 0], cov_hg[0, 1])

    # salvo le rette
    rette_hg.append({
        "p0": np.array([meanx_hg, meany_hg]),
        "d":  np.array([np.cos(theta_hg), np.sin(theta_hg)]),
        "l1": l1_hg,
        "l2": l2_hg,
        "theta": theta_hg,
        "tel": itel,
        "event": event
    })

print(f"\nRette HG calcolate: {len(rette_hg)}")

# ============================================================
# Plot HG: heatmap + rette colorate per evento
# ============================================================

fig, ax = plt.subplots(figsize=(10, 10))

# Heatmap HG
weights_hg_sum = np.array(weights_hg_sum)
h = ax.hist2d(
    x_pix[mask_tot].flatten(), 
    y_pix[mask_tot].flatten(),
    weights=weights_hg_sum[mask_tot].flatten(), 
    range=((-205, 205), (-205, 205)),
    bins=7*8, 
    cmap='Greens',
    alpha=0.7
)

# Footprint camera 
ax.plot(xfp, yfp, 'k-', linewidth=1.5, zorder=2)

# Lunghezza rette
xmin, xmax = np.min(xfp), np.max(xfp)
ymin, ymax = np.min(yfp), np.max(yfp)
diag = np.sqrt((xmax - xmin)**2 + (ymax - ymin)**2)
L = 0.40 * diag

# Rette e centroidi colorati per evento
for r in rette_hg:
    p0 = r["p0"]
    d  = r["d"]
    col = color_map[r["event"]]
    
    # Retta
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color=col, linewidth=2.5, alpha=0.85, zorder=4)
    
    # Centroide
    ax.scatter(p0[0], p0[1], s=100, color=col, edgecolor="white", linewidth=2, zorder=5)

ax.set_title(f"HG - {len(rette_hg)} rette (max 9 telescopi UNICI)", 
             fontsize=15, pad=12, fontweight='bold')
ax.set_xlim(-205, 205)
ax.set_ylim(-205, 205)
ax.set_aspect('equal')
ax.set_xlabel('x [mm]', fontsize=13)
ax.set_ylabel('y [mm]', fontsize=13)
ax.grid(True, linestyle=':', alpha=0.3)

# Legenda
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor=color_map[ev], 
          label=f'Evento {ev} ({sum(1 for r in rette_hg if r["event"] == ev)} tel)') 
    for ev in unique_events
]
ax.legend(handles=legend_elements, loc='upper right', fontsize=12, framealpha=0.95)

cbar = fig.colorbar(h[3], ax=ax, label='Segnale HG somma', pad=0.02)
cbar.ax.tick_params(labelsize=11)

plt.tight_layout()
plt.show()

print(f"\nRiepilogo:")
print(f"  Evento {unique_events[0]}: {sum(1 for r in rette_hg if r['event'] == unique_events[0])} rette")
print(f"  Evento {unique_events[1]}: {sum(1 for r in rette_hg if r['event'] == unique_events[1])} rette")
print(f"  Telescopi totali unici: {len(set(r['tel'] for r in rette_hg))}")

# ============================================================
# ESPORTA df_target_filtered per analisi successive
# ============================================================
print(f"\n✓ Usa 'df_target_filtered' per tutte le analisi successive!")
print(f"✓ Contiene {len(df_target_filtered)} righe con {df_target_filtered['TEL_ID'].nunique()} telescopi UNICI.")
# Out:
# Eventi presenti: [9705 3109]
#
# === TELESCOPI DISPONIBILI PER EVENTO ===
# Evento 9705: [2, 4, 5, 7, 9]
# Evento 3109: [1, 3, 6, 8]
#
# === TELESCOPI SELEZIONATI ===
# Evento 9705: [2, 4, 5, 7, 9]
# Evento 3109: [1, 3, 6, 8]
#
# ✓ Verifica overlap: 0 telescopi in comune
#   ✓ Perfetto! Nessun telescopio condiviso tra eventi
#
# Totale telescopi selezionati: 9
# Telescopi unici usati: 9
# Verifica: tutti diversi? True
#
# Righe in df_target_filtered: 9
# Telescopi unici: 9
# TEL_ID presenti: [1, 2, 3, 4, 5, 6, 7, 8, 9]
#
# Rette HG calcolate: 9
# Riepilogo:
#   Evento 9705: 5 rette
#   Evento 3109: 4 rette
#   Telescopi totali unici: 9
#
# ✓ Usa 'df_target_filtered' per tutte le analisi successive!
# ✓ Contiene 9 righe con 9 telescopi UNICI.

# %%
import scipy.stats as sc
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import PowerNorm
from matplotlib.patches import Ellipse

xfp, yfp = at.utils.camera.get_xy_footprint() 
y_pix, x_pix = at.utils.camera.get_pixels_position_matrix().T

x_pix = at.reshape(x_pix)
y_pix = at.reshape(y_pix)

# ============================================================
# SELEZIONE TELESCOPI: CONTROLLO MANUALE per ogni evento
# ============================================================

unique_events = df_target["EVENT"].unique()
print(f"Eventi presenti: {unique_events}")

# Prima mostriamo tutti i telescopi disponibili per ogni evento
print("\n=== TELESCOPI DISPONIBILI PER EVENTO ===")
telescopes_by_event = {}
for event in unique_events:
    event_mask = df_target["EVENT"] == event
    telescopes_by_event[event] = sorted(df_target[event_mask]["TEL_ID"].unique().tolist())
    print(f"Evento {event}: {telescopes_by_event[event]}")

# ============================================================
# 🔧 CONFIGURAZIONE MANUALE - MODIFICA QUI I TELESCOPI
# ============================================================
selected_telescopes_by_event = {3109: [1, 3, 6, 8], 9705: [2, 4, 5, 7, 9]}

print("\n=== TELESCOPI SELEZIONATI ===")
for event in unique_events:
    print(f"Evento {event}: {selected_telescopes_by_event[event]}")

# Verifica overlap tra eventi
events_list = list(unique_events)
if len(events_list) >= 2:
    set_event_0 = set(selected_telescopes_by_event[events_list[0]])
    set_event_1 = set(selected_telescopes_by_event[events_list[1]])
    overlap = set_event_0.intersection(set_event_1)
    if not overlap:
        print(f"✓ Perfetto! Nessun telescopio condiviso tra eventi")

# Crea gli indici selezionati
selected_indices = []
all_used_telescopes = set()

for event in unique_events:
    for tel in selected_telescopes_by_event[event]:
        tel_mask = (df_target["EVENT"] == event) & (df_target["TEL_ID"] == tel)
        matching_indices = df_target[tel_mask].index.tolist()
        if matching_indices:
            selected_indices.append(matching_indices[0])
            all_used_telescopes.add(tel)

# Crea dataframe filtrato
df_target_filtered = df_target.loc[selected_indices].copy()

print(f"\nRighe in df_target_filtered: {len(df_target_filtered)}")
print(f"Telescopi unici: {df_target_filtered['TEL_ID'].nunique()}")

# ============================================================
# Calcolo ellissi sui telescopi selezionati (usando HG)
# ============================================================

color_list = ["#FF6B35", "#004E89"]  # Arancione e Blu scuro
color_map = {events_list[0]: color_list[0], events_list[1]: color_list[1]}

ellissi_data = []
weights_sum = np.zeros_like(np.array(df_target_filtered['HG'].iloc[0]))
mask_tot = np.zeros((37, 64), dtype=bool)

for iv in range(len(df_target_filtered)):

    itel = df_target_filtered["TEL_ID"].iloc[iv]
    event = df_target_filtered["EVENT"].iloc[iv]
    hgev = np.array(df_target_filtered['HG'].iloc[iv])
    ttpev = np.array(df_target_filtered['TTP'].iloc[iv])

    # mask di pixel buoni
    pxmask = (hgev > 2400) & (ttpev < 255)

    # Accumulo per heatmap
    weights_sum[pxmask] += hgev[pxmask]
    mask_tot |= pxmask

    # SIGMA-CLIPPING
    xx = x_pix[pxmask].flatten()
    yy = y_pix[pxmask].flatten()
    w_hg = hgev[pxmask].flatten()

    if len(xx) == 0:
        continue

    mx0 = np.average(xx, weights=w_hg)
    my0 = np.average(yy, weights=w_hg)

    r = np.sqrt((xx - mx0)**2 + (yy - my0)**2)

    r_clip, low, high = sc.sigmaclip(r, low=3.0, high=3.0)
    keep = (r >= low) & (r <= high)

    xx_sc = xx[keep]
    yy_sc = yy[keep]
    w_hg_sc = w_hg[keep]

    if len(xx_sc) == 0:
        continue

    # centroidi
    meanx = np.average(xx_sc, weights=w_hg_sc)
    meany = np.average(yy_sc, weights=w_hg_sc)

    # covarianze
    cov = np.cov([xx_sc, yy_sc], aweights=w_hg_sc)

    # parametri ellisse
    trace = cov[0, 0] + cov[1, 1]
    det_diff = ((cov[0, 0] - cov[1, 1]) / 2) ** 2 + cov[0, 1] ** 2
    sqrt_det = np.sqrt(det_diff)
    
    l1 = trace / 2 + sqrt_det  # autovalore maggiore
    l2 = trace / 2 - sqrt_det  # autovalore minore
    theta = np.arctan2(l1 - cov[0, 0], cov[0, 1])

    # salvo i dati dell'ellisse
    ellissi_data.append({
        "p0": np.array([meanx, meany]),
        "l1": l1,
        "l2": l2,
        "theta": theta,
        "tel": itel,
        "event": event
    })

print(f"\nEllissi calcolate: {len(ellissi_data)}")

# ============================================================
# Plot unico con entrambi gli eventi e assi maggiore/minore
# ============================================================

fig, ax = plt.subplots(figsize=(14, 14))

# Heatmap combinata
weights_sum = np.array(weights_sum)
h = ax.hist2d(
    x_pix[mask_tot].flatten(), 
    y_pix[mask_tot].flatten(),
    weights=weights_sum[mask_tot].flatten(), 
    range=((-205, 205), (-205, 205)),
    bins=7*8, 
    cmap='Greys',
    alpha=0.4,
    norm=PowerNorm(gamma=0.3)
)

# Footprint camera 
ax.plot(xfp, yfp, 'k-', linewidth=2, zorder=2, label='Camera footprint')

# Ellissi con assi maggiore e minore
for ell in ellissi_data:
    p0 = ell["p0"]
    col = color_map[ell["event"]]
    
    # Ellisse (2 sigma)
    width = 2 * np.sqrt(ell["l1"]) * 2  # asse maggiore
    height = 2 * np.sqrt(ell["l2"]) * 2  # asse minore
    angle = np.degrees(ell["theta"])
    
    ellipse = Ellipse(
        xy=p0, 
        width=width, 
        height=height, 
        angle=angle,
        edgecolor=col, 
        facecolor=col,
        linewidth=3, 
        alpha=0.25,
        zorder=3
    )
    ax.add_patch(ellipse)
    
    # Bordo ellisse più marcato
    ellipse_border = Ellipse(
        xy=p0, 
        width=width, 
        height=height, 
        angle=angle,
        edgecolor=col, 
        facecolor='none',
        linewidth=2.5, 
        alpha=0.9,
        zorder=4
    )
    ax.add_patch(ellipse_border)
    
    # Asse maggiore
    cos_t = np.cos(ell["theta"])
    sin_t = np.sin(ell["theta"])
    major_half = np.sqrt(ell["l1"]) * 2  # 2 sigma
    
    ax.plot(
        [p0[0] - major_half * cos_t, p0[0] + major_half * cos_t],
        [p0[1] - major_half * sin_t, p0[1] + major_half * sin_t],
        color=col, linewidth=2.5, alpha=0.8, linestyle='-', zorder=5
    )
    
    # Asse minore
    minor_half = np.sqrt(ell["l2"]) * 2  # 2 sigma
    ax.plot(
        [p0[0] + minor_half * sin_t, p0[0] - minor_half * sin_t],
        [p0[1] - minor_half * cos_t, p0[1] + minor_half * cos_t],
        color=col, linewidth=2.5, alpha=0.8, linestyle='--', zorder=5
    )
    
    # Centroide
    ax.scatter(p0[0], p0[1], s=150, color=col, edgecolor="white", linewidth=2.5, zorder=6, marker='o')

ax.set_title(f"Immagini Cherenkov - {len(ellissi_data)} telescopi (2 eventi)", 
             fontsize=18, pad=15, fontweight='bold')
ax.set_xlim(-210, 210)
ax.set_ylim(-210, 210)
ax.set_aspect('equal')
ax.set_xlabel('x [mm]', fontsize=15, fontweight='bold')
ax.set_ylabel('y [mm]', fontsize=15, fontweight='bold')
ax.grid(True, linestyle=':', alpha=0.4, linewidth=1)

# Legenda dettagliata
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

legend_elements = [
    Patch(facecolor=color_map[events_list[0]], alpha=0.5, edgecolor=color_map[events_list[0]], 
          linewidth=2, label=f'Evento {events_list[0]} ({len([e for e in ellissi_data if e["event"] == events_list[0]])} tel)'),
    Patch(facecolor=color_map[events_list[1]], alpha=0.5, edgecolor=color_map[events_list[1]], 
          linewidth=2, label=f'Evento {events_list[1]} ({len([e for e in ellissi_data if e["event"] == events_list[1]])} tel)'),
    Line2D([0], [0], color='gray', linewidth=2.5, linestyle='-', label='Asse maggiore'),
    Line2D([0], [0], color='gray', linewidth=2.5, linestyle='--', label='Asse minore'),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='gray', markersize=10, 
           markeredgecolor='white', markeredgewidth=2, linestyle='', label='Centroide')
]

ax.legend(handles=legend_elements, loc='upper left', fontsize=13, framealpha=0.95, 
          edgecolor='black', fancybox=True, shadow=True)

# Colorbar più piccola
cbar = fig.colorbar(h[3], ax=ax, label='Segnale HG', pad=0.02, fraction=0.046)
cbar.ax.tick_params(labelsize=11)

plt.tight_layout()
plt.show()

print(f"\nRiepilogo:")
print(f"  Evento {events_list[0]}: {len([e for e in ellissi_data if e['event'] == events_list[0]])} ellissi")
print(f"  Evento {events_list[1]}: {len([e for e in ellissi_data if e['event'] == events_list[1]])} ellissi")
print(f"  Telescopi totali unici: {len(all_used_telescopes)}")

print(f"\n✓ Plot ottimizzato per visualizzare chiaramente i due eventi!")
# Out:
# Eventi presenti: [9705 3109]
#
# === TELESCOPI DISPONIBILI PER EVENTO ===
# Evento 9705: [2, 4, 5, 7, 9]
# Evento 3109: [1, 3, 6, 8]
#
# === TELESCOPI SELEZIONATI ===
# Evento 9705: [2, 4, 5, 7, 9]
# Evento 3109: [1, 3, 6, 8]
# ✓ Perfetto! Nessun telescopio condiviso tra eventi
#
# Righe in df_target_filtered: 9
# Telescopi unici: 9
#
# Ellissi calcolate: 9
# Riepilogo:
#   Evento 9705: 5 ellissi
#   Evento 3109: 4 ellissi
#   Telescopi totali unici: 9
#
# ✓ Plot ottimizzato per visualizzare chiaramente i due eventi!

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import PowerNorm
from matplotlib.patches import Ellipse
import scipy.stats as sc

# ============================================================
# Camera geometry
# ============================================================

xfp, yfp = at.utils.camera.get_xy_footprint()
y_pix, x_pix = at.utils.camera.get_pixels_position_matrix().T

x_pix = at.reshape(x_pix)
y_pix = at.reshape(y_pix)

# ============================================================
# Setup eventi e colori
# ============================================================

unique_events = df_target["EVENT"].unique()
color_list = ["tab:red", "tab:blue", "tab:green", "tab:orange"]
color_map = {ev: color_list[i % len(color_list)] for i, ev in enumerate(unique_events)}

# accumulatori per heatmap per evento
weights_hg_per_event = {ev: np.zeros_like(np.array(df_target['HG'])[0]) for ev in unique_events}
mask_per_event = {ev: np.zeros((37, 64), dtype=bool) for ev in unique_events}

# container risultati
rette_hg = []

# ============================================================
# Loop principale: rette + ellissi
# ============================================================

for iv in range(len(df_target)):

    itel  = df_target["TEL_ID"].iloc[iv]
    event = df_target["EVENT"].iloc[iv]

    hgev  = np.array(df_target['HG'])[iv]
    ttpev = np.array(df_target['TTP'])[iv]

    # pixel buoni
    pxmask = (hgev > 2400) & (ttpev < 255)

    if not np.any(pxmask):
        continue

    # accumulo heatmap per evento
    weights_hg_per_event[event][pxmask] += hgev[pxmask]
    mask_per_event[event] |= pxmask

    # coordinate + pesi
    xx = x_pix[pxmask].flatten()
    yy = y_pix[pxmask].flatten()
    w  = hgev[pxmask].flatten()

    # centro grezzo
    mx0 = np.average(xx, weights=w)
    my0 = np.average(yy, weights=w)

    # sigma-clip radiale
    r = np.sqrt((xx - mx0)**2 + (yy - my0)**2)
    _, low, high = sc.sigmaclip(r, low=3.0, high=3.0)
    keep = (r >= low) & (r <= high)

    if np.sum(keep) < 3:
        continue

    xx = xx[keep]
    yy = yy[keep]
    w  = w[keep]

    # centroidi finali
    meanx = np.average(xx, weights=w)
    meany = np.average(yy, weights=w)

    # covarianza pesata
    cov = np.cov([xx, yy], aweights=w)

    # autovalori + angolo (come nel tuo codice ellissi)
    trace = cov[0, 0] + cov[1, 1]
    det_d = ((cov[0, 0] - cov[1, 1]) / 2) ** 2 + cov[0, 1] ** 2
    root  = np.sqrt(det_d)

    l1 = trace / 2 + root
    l2 = trace / 2 - root
    theta = np.arctan2(l1 - cov[0, 0], cov[0, 1])

    # salvo tutto
    rette_hg.append({
        "p0": np.array([meanx, meany]),
        "d":  np.array([np.cos(theta), np.sin(theta)]),
        "l1": l1,
        "l2": l2,
        "theta": theta,
        "tel": itel,
        "event": event
    })

# ============================================================
# Lunghezza estetica delle rette
# ============================================================

xmin, xmax = np.min(xfp), np.max(xfp)
ymin, ymax = np.min(yfp), np.max(yfp)
diag = np.sqrt((xmax - xmin)**2 + (ymax - ymin)**2)
L = 0.40 * diag

# ============================================================
# Plot separato per ogni EVENTO (HG)
# ============================================================

for event in unique_events:

    fig, ax = plt.subplots(figsize=(12, 10))

    weights = weights_hg_per_event[event]
    mask_ev = mask_per_event[event]

    if np.any(mask_ev):
        h = ax.hist2d(
            x_pix[mask_ev].flatten(),
            y_pix[mask_ev].flatten(),
            weights=weights[mask_ev].flatten(),
            range=((-205, 205), (-205, 205)),
            bins=7*8,
            norm=PowerNorm(gamma=0.3),
            cmap='Greens'
        )
        fig.colorbar(h[3], ax=ax, label='Segnale HG')

    # footprint camera
    ax.plot(xfp, yfp, 'k-', linewidth=1.8, zorder=2)

    col = color_map[event]

    for r in rette_hg:
        if r["event"] != event:
            continue

        p0 = r["p0"]
        d  = r["d"]

        # centroide
        ax.scatter(p0[0], p0[1], s=110, color=col,
                   edgecolor='white', linewidth=1.8, zorder=6)

        # retta Hillas
        ax.plot(
            [p0[0] - L*d[0], p0[0] + L*d[0]],
            [p0[1] - L*d[1], p0[1] + L*d[1]],
            color=col, linewidth=2.8, alpha=0.9, zorder=5
        )

        # ellisse 2σ
        width  = 2 * np.sqrt(r["l1"]) * 2
        height = 2 * np.sqrt(r["l2"]) * 2
        angle  = np.degrees(r["theta"])

        ell = Ellipse(
            xy=p0, width=width, height=height, angle=angle,
            facecolor=col, edgecolor=col,
            alpha=0.25, linewidth=2.5, zorder=3
        )
        ax.add_patch(ell)

        ell_b = Ellipse(
            xy=p0, width=width, height=height, angle=angle,
            facecolor='none', edgecolor=col,
            linewidth=2.5, alpha=0.9, zorder=4
        )
        ax.add_patch(ell_b)

    ax.set_title(f"HG – EVENT {event}", fontsize=15, pad=12)
    ax.set_xlim(-205, 205)
    ax.set_ylim(-205, 205)
    ax.set_aspect('equal')
    ax.set_xlabel("x [mm]")
    ax.set_ylabel("y [mm]")
    ax.grid(True, linestyle=':', alpha=0.4)

    plt.tight_layout()
    plt.show()

print(f"Rette / ellissi totali: {len(rette_hg)}")
# Out:
# Rette / ellissi totali: 9

# %%
xmin, xmax = np.min(xfp), np.max(xfp)
ymin, ymax = np.min(yfp), np.max(yfp)
diag = np.sqrt((xmax - xmin)**2 + (ymax - ymin)**2)
L = 0.4* diag
fig, ax = plt.subplots(figsize=(6, 6))
# footprint camera 
ax.plot(xfp, yfp, 'k-', linewidth=1)

# calcolo lunghezza estetica delle rette
xmin, xmax = np.min(xfp), np.max(xfp)
ymin, ymax = np.min(yfp), np.max(yfp)
diag = np.sqrt((xmax - xmin)**2 + (ymax - ymin)**2)
L = 0.80 * diag
centro_hg=np.mean(v_hg,axis=0)
centro_lg=np.mean(v_lg,axis=0)

median_hg=np.median(v_hg,axis=0)
median_lg=np.median(v_lg,axis=0)
# centroidi e rette HG
for r in rette_hg:
    p0 = r["p0"]
    d  = r["d"]

    # centroide HG (punto rosso grande)
    ax.scatter(p0[0], p0[1], s=80, color="firebrick", zorder=5)

    # retta lunga HG (firebrick)
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color="firebrick", linewidth=2, alpha=0.8)

#  centroidi e rette LG 
for r in rette_lg:
    p0 = r["p0"]
    d  = r["d"]

    # centroide LG (punto grigio più piccolo con bordo nero)
    ax.scatter(p0[0], p0[1], s=60, color="grey", edgecolor="black", zorder=5)

    # retta lunga LG (grey)
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color="grey", linewidth=2, alpha=0.8)

ax.set_title("rette  due eventi")
ax.set_xlim(-250,250 )
ax.set_ylim(-250,250)


ax.scatter(v_hg[:,0], v_hg[:,1], marker="o",c="blue",edgecolor="black",zorder=5)
ax.scatter(v_lg[:,0], v_lg[:,1], marker="o",c="yellow",edgecolor="black",zorder=5)
ax.set_aspect('equal', 'box')
ax.grid(False)
ax.set_title("Ricostruzione direzioni + intersezioni", fontsize=14)
plt.tight_layout()


ax.set_xlabel("x(mm)")
ax.set_ylabel("y(mm)")
ax.set_xlim(-250, 250)
ax.set_ylim(-250, 250)
'''
ax.scatter(centro_lg[0], centro_lg[1],zorder=5, 
                    color='cyan', edgecolor='black',
                    s=120, marker='o', label='Media delle intersezioni LG')
ax.scatter(median_lg[0], median_lg[1], 
                    color='cyan', edgecolor='black',zorder=5,
                    s=120, marker='*', label='Mediana della intersezioni LG')

ax.scatter(centro_hg[0], centro_hg[1],zorder=5, 
                    color='red', edgecolor='black',
                    s=120, marker='o', label='Media delle intersezioni HG')
ax.scatter(median_hg[0], median_hg[1], 
                    color='red', edgecolor='black',zorder=5,
                    s=120, marker='*', label='Mediana della intersezioni HG')
'''
 #dummy legends
ax.scatter([], [], color='firebrick', s=80, label="mean HG")
ax.scatter([], [], color='grey', s=60, edgecolor='black', label="mean LG")
ax.plot([], [], color='firebrick', linewidth=2, alpha=0.7, label="Direzione HG")
ax.plot([], [], color='grey', linewidth=2, alpha=0.7, label="Direzione LG")
ax.scatter([], [], c="blue", edgecolor="black",label="intersezione HG")
ax.scatter([], [], c="yellow", edgecolor="black",label="intersezione LG")
ax.legend(loc="lower left")



plt.show()

# %%
dists_hg = []
for i in range(N):
    for j in range(i+1, N):
        dij = np.linalg.norm(v_hg[i] - v_hg[j])
        dists_hg.append(dij)
dists_hg = np.array(dists_hg)

dists_lg = []
for i in range(N):
    for j in range(i+1, N):
        dij = np.linalg.norm(v_lg[i] - v_lg[j])
        dists_lg.append(dij)
dists_lg = np.array(dists_lg)
centro_hg=np.mean(v_hg,axis=0)
centro_lg=np.mean(v_lg,axis=0)

median_hg=np.median(v_hg,axis=0)
median_lg=np.median(v_lg,axis=0)
#distanza euclidea punto-punto
dists_center_lg = np.linalg.norm(v_lg - centro_lg, axis=1)
dists_median_lg = np.linalg.norm(v_lg - median_lg, axis=1)

dists_center_hg = np.linalg.norm(v_hg - centro_hg, axis=1)
dists_median_hg = np.linalg.norm(v_hg - median_hg, axis=1)
#distribuzione relative tra le intersezioni per riuscire a dividere baricentro e media

fig, axes = plt.subplots(3, 2, figsize=(12, 12))

# -------------------- HG --------------------
#  distanze tra coppie
axes[0,0].hist(dists_hg, bins=50, edgecolor='black')
axes[0,0].set_title("Distanze relative (HG)")
axes[0,0].set_ylabel("Conteggio")

#  distanze dal baricentro
axes[1,0].hist(dists_center_hg, bins=50, edgecolor='black')
axes[1,0].set_title("Distanza dalla media (HG)")
axes[1,0].set_ylabel("Conteggio")

#  distanze dalla mediana
axes[2,0].hist(dists_median_hg, bins=50, edgecolor='black')
axes[2,0].set_title("Distanza dalla mediana (HG)")
axes[2,0].set_xlabel("Distanza (mm)")
axes[2,0].set_ylabel("Conteggio")

# -------------------- LG --------------------
#  distanze tra coppie
axes[0,1].hist(dists_lg, bins=50, edgecolor='black')
axes[0,1].set_title("Distanze relative (LG)")

#  distanze dal baricentro
axes[1,1].hist(dists_center_lg, bins=50, edgecolor='black')
axes[1,1].set_title("Distanza dalla media (LG)")

#  distanze dalla mediana
axes[2,1].hist(dists_median_lg, bins=50, edgecolor='black')
axes[2,1].set_title("Distanza dalla mediana (LG)")
axes[2,1].set_xlabel("Distanza (mm)")

plt.tight_layout()
plt.show()

# %%
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors

def plot_k_distance_graph(X, k):
    neigh = NearestNeighbors(n_neighbors=k)
    neigh.fit(X)
    distances, _ = neigh.kneighbors(X)
    distances = np.sort(distances[:, k-1])
    plt.figure(figsize=(10, 6))
    plt.plot(distances)
    plt.xlabel('Points')
    plt.ylabel(f'{k}-th nearest neighbor distance')
    plt.title('K-distance Graph')
    plt.grid()
    plt.show()
# Plot k-distance graph
plot_k_distance_graph(v_hg, k=5)
#per sciegliere il punto sul gomito===> intorno a 100 (anche da istogrammi)

# %%
# Perform DBSCAN clustering
epsilon = 30 # (20)
min_samples = 3 # (6)
dbscan = DBSCAN(eps=epsilon, min_samples=min_samples)
clusters = dbscan.fit_predict(v_hg)
#suddivido i punti in base al cluster
cluster0 = v_hg[clusters == 0]
cluster1 = v_hg[clusters == 1]
#mi calcolo la mediana dei punti del cluster 0 o 1
centro0 =np.median(cluster0,axis=0)
centro1=np.median(cluster1,axis=0)
plt.figure(figsize=(7, 6))
plt.plot(xfp, yfp, 'k-', linewidth=1)
scatter = plt.scatter(v_hg[:, 0], v_hg[:, 1], c=clusters, cmap='viridis',edgecolor="black")
plt.scatter(centro0[0],centro0[ 1], marker='+',c='red')
plt.scatter(centro1[0],centro1[ 1], marker='+',c='red')

plt.colorbar(scatter)
plt.title('DBSCAN Clustering Results')
plt.xlabel('x (mm)')
plt.ylabel('y(mm)')
plt.xlim(-250,250)
plt.ylim(-250,250)
plt.show()

# %%
#per powerpoint
# --- DBSCAN ---
epsilon = 20  # Chosen based on k-distance graph
min_samples = 5  # 2 * num_features (2D data)
dbscan = DBSCAN(eps=epsilon, min_samples=min_samples)
clusters = dbscan.fit_predict(v_hg)

# suddivido i punti in base al cluster
cluster0 = v_hg[clusters == 0]
cluster1 = v_hg[clusters == 1]

# mediane dei punti dei cluster
centro0 = np.median(cluster0, axis=0)
centro1 = np.median(cluster1, axis=0)

# --- FIGURA UNICA ---
fig, ax = plt.subplots(figsize=(6, 6))

# footprint camera
ax.plot(xfp, yfp, 'k-', linewidth=1)

# scatter DBSCAN
scatter = ax.scatter(v_hg[:, 0], v_hg[:, 1], c=clusters, cmap='viridis',zorder=5,edgecolor="black")

# centroidi DBSCAN
ax.scatter(centro0[0], centro0[1], marker='+', s=120, c='red',zorder=6)
ax.scatter(centro1[0], centro1[1], marker='.', s=120, c='red',zorder=6)

# --- lunghezza estetica delle rette ---
xmin, xmax = np.min(xfp), np.max(xfp)
ymin, ymax = np.min(yfp), np.max(yfp)
diag = np.sqrt((xmax - xmin)**2 + (ymax - ymin)**2)
L = 0.40 * diag

# --- rette HG ---
for r in rette_hg:
    p0 = r["p0"]
    d  = r["d"]



    # retta HG
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color="firebrick", linewidth=2, alpha=0.5)

# --- rette LG ---
for r in rette_lg:
    p0 = r["p0"]
    d  = r["d"]
    # retta LG
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color="grey", linewidth=2, alpha=0.5)

# --- estetica ---
#fig.colorbar(scatter, ax=ax, label="Cluster label")
ax.set_title("DBSCAN + rette HG/LG")
ax.set_xlim(-250, 250)
ax.set_ylim(-250, 250)
ax.set_xlabel("x(mm)")
ax.set_ylabel("y(mm)")

plt.tight_layout()
 #dummy legends
ax.scatter([], [], color='gold', s=60, edgecolor='black', label="cluster 2")
ax.scatter([], [], color='darkcyan', s=60, edgecolor='black', label="cluster 1")
ax.scatter([], [], color='indigo', s=60, edgecolor='black', label="non associati a cluster")
ax.scatter([], [], color='red', s=120,marker="+", label="mediana cluster 1")
ax.scatter([], [], color='red', s=120,marker=".", label="mediana cluster 2")
ax.plot([], [], color='firebrick', linewidth=2, alpha=0.7, label="Direzione HG")
ax.plot([], [], color='grey', linewidth=2, alpha=0.7, label="Direzione LG")

ax.legend(loc="lower left")


plt.show()

# %%
#per ora solo rette hg e utilizzo mediana
r_median1 = []
r_median0=[]

for r in rette_hg:

    p0 = r["p0"]
    d  = r["d"]  
    # normalizzazione
    norm_d = np.linalg.norm(d)
    if norm_d == 0:
        continue
    d_unit = d / norm_d

    # vettore da p0 al punto P
    v = centro0 - p0
    u = centro1 - p0
    # distanza punto–retta
    dist0 = abs(v[0] * d_unit[1] - v[1] * d_unit[0])
    dist1=abs(u[0] * d_unit[1] - u[1] * d_unit[0])

    r_median1.append(dist0)
    r_median0.append(dist1)
    # filtro 
    if dist0 < 5:
        r["event"]=0

    if dist1 < 5:
        r["event"]=1
r_median1 = np.array(r_median1)
r_median0= np.array(r_median0)
'''
r_mean_lg = []
r_median_lg=[]
for r in rette_lg:

    p0 = r["p0"]
    d  = r["d"]  

    # normalizzazione
    norm_d = np.linalg.norm(d)
    if norm_d == 0:
        continue
    d_unit = d / norm_d

    # vettore da p0 al punto P
    v = centro_hg - p0
    u = median_hg - p0
    # distanza punto–retta
    dist_mean = abs(v[0] * d_unit[1] - v[1] * d_unit[0])
    dist_median=abs(u[0] * d_unit[1] - u[1] * d_unit[0])

    r_mean_lg.append(dist_mean)
    r_median_lg.append(dist_median)
r_mean_lg = np.array(r_mean_lg)
r_median_lg= np.array(r_median_lg)
'''
# -----------------------------
# Istogramma
# -----------------------------
fig, axes = plt.subplots(2, 1, figsize=(8, 6), sharex='col')

# -------------------- HG --------------------
#  distanze tra coppie
axes[0].hist(r_median1, bins=80, edgecolor='black')
axes[0].set_title("Distanze retta-mediana cluster 1 (HG)")
axes[0].set_ylabel("Conteggio")
axes[0].set_xlabel("Distanza (mm)")

#  distanze dal baricentro
axes[1].hist(r_median0, bins=80, edgecolor='black')
axes[1].set_title("Distanza retta-mediana cluster 2 (HG)")
axes[1].set_ylabel("Conteggio")
axes[1].set_xlabel("Distanza (mm)")



# -------------------- LG --------------------
#  distanze tra coppie
#axes[0,1].hist(r_mean_lg, bins=50, edgecolor='black')
#axes[0,1].set_title("Distanze retta-media (LG)")

#  distanze dal baricentro
#axes[1,1].hist(r_median_lg, bins=50, edgecolor='black')
#axes[1,1].set_title("Distanza retta-mediana (LG)")
#axes[1,1].set_xlabel("Distanza (mm)")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.metrics import adjusted_rand_score, confusion_matrix, fowlkes_mallows_score

# ============================================================ev
# DBSCAN clustering sulle intersezioni v_hg
# ============================================================

epsilon = 20
min_samples = 5
dbscan = DBSCAN(eps=epsilon, min_samples=min_samples)
clusters_dbscan = dbscan.fit_predict(v_hg)

# Mediane dei cluster
cluster0 = v_hg[clusters_dbscan == 0]
cluster1 = v_hg[clusters_dbscan == 1]
centro0 = np.median(cluster0, axis=0)
centro1 = np.median(cluster1, axis=0)

print("="*70)
print("DBSCAN CLUSTERING")
print("="*70)
print(f"Epsilon: {epsilon}, Min samples: {min_samples}")
print(f"Cluster 0: {len(cluster0)} intersezioni, mediana: {centro0}")
print(f"Cluster 1: {len(cluster1)} intersezioni, mediana: {centro1}")
print(f"Outliers (cluster -1): {np.sum(clusters_dbscan == -1)} intersezioni")
print("="*70)

# ============================================================
# Assegnazione rette ai cluster DBSCAN (distanza punto-retta)
# ============================================================

eventi_dbscan = []

for r in rette_hg:
    p0 = r["p0"]
    d = r["d"]
    
    # Normalizzazione
    norm_d = np.linalg.norm(d)
    if norm_d == 0:
        eventi_dbscan.append(-1)  # invalida
        continue
    d_unit = d / norm_d
    
    # Distanze dalla retta ai centri dei cluster
    v0 = centro0 - p0
    v1 = centro1 - p0
    dist0 = abs(v0[0] * d_unit[1] - v0[1] * d_unit[0])
    dist1 = abs(v1[0] * d_unit[1] - v1[1] * d_unit[0])
    
    # Assegna al cluster più vicino (con soglia)
    if dist0 < 10:
        eventi_dbscan.append(0)
    elif dist1 < 10:
        eventi_dbscan.append(1)
    else:
        eventi_dbscan.append(-1)  # outlier

eventi_dbscan = np.array(eventi_dbscan)

# ============================================================
# Estrazione verità Monte Carlo
# ============================================================

eventi_mc = []

for r in rette_hg:
    eventi_mc.append(r["event"])
    
eventi_mc = np.array(eventi_mc)

unique_events_mc = np.unique(eventi_mc)
print(f"\nEventi Monte Carlo presenti: {unique_events_mc}")
print(f"Numero di eventi: {len(unique_events_mc)}")

# ============================================================
# Confronto: DBSCAN vs Monte Carlo
# ============================================================

# Filtra solo le rette che DBSCAN ha assegnato a un cluster (non outliers)
mask_validi = eventi_dbscan != -1

eventi_dbscan_validi = eventi_dbscan[mask_validi]
eventi_mc_validi = eventi_mc[mask_validi]

# Metriche di clustering
ari = adjusted_rand_score(eventi_mc_validi, eventi_dbscan_validi)
fmi = fowlkes_mallows_score(eventi_mc_validi, eventi_dbscan_validi)

print("\n" + "="*70)
print("CONFRONTO: DBSCAN vs MONTE CARLO")
print("="*70)
print(f"Rette totali: {len(eventi_mc)}")
print(f"Rette assegnate da DBSCAN: {np.sum(mask_validi)}")
print(f"Rette outlier DBSCAN: {np.sum(~mask_validi)}")
print(f"\nAdjusted Rand Index: {ari:.3f}")
print(f"Fowlkes-Mallows Index: {fmi:.3f}")
print(f"(1.0 = perfetto accordo, 0.0 = casuale)")

# Analisi per cluster
print("\n" + "-"*70)
print("ANALISI PUREZZA CLUSTER:")
print("-"*70)

for cluster_id in [0, 1]:
    mask_cluster = eventi_dbscan_validi == cluster_id
    if np.sum(mask_cluster) == 0:
        continue
    
    eventi_in_cluster = eventi_mc_validi[mask_cluster]
    unique, counts = np.unique(eventi_in_cluster, return_counts=True)
    
    print(f"\nCluster DBSCAN {cluster_id}:")
    print(f"  Totale rette: {len(eventi_in_cluster)}")
    for ev, count in zip(unique, counts):
        percentage = 100 * count / len(eventi_in_cluster)
        print(f"    Evento MC {ev}: {count} rette ({percentage:.1f}%)")
    
    # Purezza del cluster (% della classe più rappresentata)
    purezza = np.max(counts) / len(eventi_in_cluster)
    print(f"  Purezza: {purezza:.1%}")

print("="*70)

# ============================================================
# Plot 1: Confronto side-by-side
# ============================================================

# Crea colormap dinamica per gli eventi MC
from matplotlib.colors import ListedColormap
n_events = len(unique_events_mc)
if n_events == 2:
    colors_mc = ["royalblue", "orange"]
else:
    # Se ci sono più di 2 eventi, usa una colormap
    colors_mc = plt.cm.tab10(np.linspace(0, 1, n_events))

# Mappa evento -> colore
event_to_color = {ev: colors_mc[i] for i, ev in enumerate(unique_events_mc)}

colori_dbscan = {0: "red", 1: "green", -1: "gray"}

# Lunghezza rette
xmin, xmax = np.min(xfp), np.max(xfp)
ymin, ymax = np.min(yfp), np.max(yfp)
diag = np.sqrt((xmax - xmin)**2 + (ymax - ymin)**2)
L = 0.40 * diag

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# ─── Plot 1: Eventi Monte Carlo (verità) ───────────────────
ax = axes[0]
ax.plot(xfp, yfp, 'k-', linewidth=1.5, zorder=1)

for i, r in enumerate(rette_hg):
    p0 = r["p0"]
    d = r["d"]
    col = event_to_color[eventi_mc[i]]
    
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color=col, linewidth=2.5, alpha=0.85, zorder=3)
    ax.scatter(p0[0], p0[1], s=100, color=col, edgecolor="white", linewidth=2, zorder=4)

ax.set_title("VERITÀ MONTE CARLO ", fontsize=15, fontweight='bold', pad=12)
ax.set_xlim(-250, 250)
ax.set_ylim(-250, 250)
ax.set_aspect('equal')
ax.set_xlabel('x [mm]', fontsize=13)
ax.set_ylabel('y [mm]', fontsize=13)
ax.grid(True, linestyle=':', alpha=0.3)

from matplotlib.patches import Patch
legend_mc = [Patch(facecolor=event_to_color[ev], label=f'MC Event {ev}') 
             for ev in unique_events_mc]
ax.legend(handles=legend_mc, loc='upper right', fontsize=12, framealpha=0.95)

# ─── Plot 2: Clustering DBSCAN ─────────────────────────────
ax = axes[1]
ax.plot(xfp, yfp, 'k-', linewidth=1.5, zorder=1)

for i, r in enumerate(rette_hg):
    p0 = r["p0"]
    d = r["d"]
    cluster = eventi_dbscan[i]
    col = colori_dbscan[cluster]
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    
    alpha = 0.85 if cluster != -1 else 0.4
    lw = 2.5 if cluster != -1 else 1.5
    
    ax.plot([x1, x2], [y1, y2], color=col, linewidth=lw, alpha=alpha, zorder=3)
    ax.scatter(p0[0], p0[1], s=100, color=col, edgecolor="white", linewidth=2, zorder=4)

# Mediane cluster
ax.scatter(centro0[0], centro0[1], marker='+', s=400, c='darkred', linewidth=3, zorder=5)
ax.scatter(centro1[0], centro1[1], marker='+', s=400, c='darkgreen', linewidth=3, zorder=5)

ax.set_title(f"DBSCAN CLUSTERING ", fontsize=15, fontweight='bold', pad=12)
ax.set_xlim(-250, 250)
ax.set_ylim(-250, 250)
ax.set_aspect('equal')
ax.set_xlabel('x [mm]', fontsize=13)
ax.set_ylabel('y [mm]', fontsize=13)
ax.grid(True, linestyle=':', alpha=0.3)

legend_dbscan = [
    Patch(facecolor='red', label='DBSCAN Cluster 0'),
    Patch(facecolor='green', label='DBSCAN Cluster 1'),
    Patch(facecolor='gray', label='Outliers')
]
ax.legend(handles=legend_dbscan, loc='upper right', fontsize=12, framealpha=0.95)

plt.tight_layout()
plt.show()

# ============================================================
# Plot 2: Colora le rette in base a purezza del cluster
# ============================================================

# Per ogni cluster, trova l'evento MC più rappresentato
cluster_main_event = {}
for cluster_id in [0, 1]:
    mask_cluster = (eventi_dbscan == cluster_id)
    if np.sum(mask_cluster) == 0:
        continue
    eventi_in_cluster = eventi_mc[mask_cluster]
    unique, counts = np.unique(eventi_in_cluster, return_counts=True)
    # L'evento principale è quello più frequente
    cluster_main_event[cluster_id] = unique[np.argmax(counts)]

print(f"\nEvento principale per cluster:")
print(f"  Cluster 0 -> Evento MC {cluster_main_event.get(0, 'N/A')}")
print(f"  Cluster 1 -> Evento MC {cluster_main_event.get(1, 'N/A')}")

fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(xfp, yfp, 'k-', linewidth=1.5, zorder=1)

n_corrette = 0
n_sbagliate = 0
n_outliers = 0

for i, r in enumerate(rette_hg):
    p0 = r["p0"]
    d = r["d"]
    evento_mc = eventi_mc[i]
    cluster_dbscan = eventi_dbscan[i]
    
    if cluster_dbscan == -1:
        # Outlier
        col = 'purple'
        alpha = 0.5
        lw = 2.0
        marker_size = 80
        n_outliers += 1
    else:
        # Controlla se è nel cluster "giusto" (quello dove il suo evento è maggioritario)
        evento_principale = cluster_main_event.get(cluster_dbscan, None)
        
        if evento_mc == evento_principale:
            # Corretto: stesso evento dell'evento principale del cluster
            col = event_to_color[evento_mc]
            alpha = 0.85
            lw = 2.5
            marker_size = 100
            n_corrette += 1
        else:
            # Errore: evento diverso dall'evento principale del cluster
            col = 'red'
            alpha = 1.0
            lw = 4.5
            marker_size = 180
            n_sbagliate += 1
    
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color=col, linewidth=lw, alpha=alpha, zorder=3)
    ax.scatter(p0[0], p0[1], s=marker_size, color=col, 
               edgecolor="white", linewidth=2, zorder=4)

ax.set_title("Rette nel CLUSTER SBAGLIATO evidenziate in ROSSO", fontsize=15, fontweight='bold', pad=12)
ax.set_xlim(-250, 250)
ax.set_ylim(-250, 250)
ax.set_aspect('equal')
ax.set_xlabel('x [mm]', fontsize=13)
ax.set_ylabel('y [mm]', fontsize=13)
ax.grid(True, linestyle=':', alpha=0.3)

legend_elements = []
for ev in unique_events_mc:
    legend_elements.append(Patch(facecolor=event_to_color[ev], 
                                 label=f'MC Event {ev} (cluster corretto)'))
legend_elements.append(Patch(facecolor='red', label=f'Cluster sbagliato ({n_sbagliate})'))
legend_elements.append(Patch(facecolor='purple', label=f'Outliers DBSCAN ({n_outliers})'))

ax.legend(handles=legend_elements, loc='upper right', fontsize=11, framealpha=0.95)

print(f"\nRette nel cluster corretto: {n_corrette}")
print(f"Rette nel cluster sbagliato: {n_sbagliate}")
print(f"Rette outlier: {n_outliers}")

plt.tight_layout()
plt.show()
# Out:
# ...
# DBSCAN CLUSTERING
# ...
# Epsilon: 20, Min samples: 5
# Cluster 0: 7 intersezioni, mediana: [-43.558027   205.69555842]
# Cluster 1: 5 intersezioni, mediana: [ 116.54848263 -114.46758611]
# Outliers (cluster -1): 23 intersezioni
# ...
#
# Eventi Monte Carlo presenti: [0 1]
# Numero di eventi: 2
#
# ...
# CONFRONTO: DBSCAN vs MONTE CARLO
# ...
# Rette totali: 9
# Rette assegnate da DBSCAN: 9
# Rette outlier DBSCAN: 0
#
# Adjusted Rand Index: 1.000
# Fowlkes-Mallows Index: 1.000
# (1.0 = perfetto accordo, 0.0 = casuale)
#
# ----------------------------------------------------------------------
# ANALISI PUREZZA CLUSTER:
# ----------------------------------------------------------------------
#
# Cluster DBSCAN 0:
#   Totale rette: 5
#     Evento MC 0: 5 rette (100.0%)
#   Purezza: 100.0%
#
# Cluster DBSCAN 1:
#   Totale rette: 4
#     Evento MC 1: 4 rette (100.0%)
#   Purezza: 100.0%
# ...
# Evento principale per cluster:
#   Cluster 0 -> Evento MC 0
#   Cluster 1 -> Evento MC 1
#
# Rette nel cluster corretto: 9
# ...

# %%
colori = {0: "royalblue", 1: "orange"}   # colori per i due eventi
fig, ax = plt.subplots(figsize=(6, 6))
plt.plot(xfp, yfp, 'k-', linewidth=1)

for r in rette_hg:
    p0 = r["p0"]
    d  = r["d"]
    col=colori[r["event"]]
    
    # retta lunga HG (firebrick)
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color=col, linewidth=2, alpha=0.8)


ax.set_title("rette  due eventi")
ax.set_xlim(-250,250 )
ax.set_ylim(-250,250)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.metrics import adjusted_rand_score, confusion_matrix, fowlkes_mallows_score

# ============================================================
# DBSCAN clustering sulle intersezioni v_hg
# ============================================================

epsilon = 20
min_samples = 6
dbscan = DBSCAN(eps=epsilon, min_samples=min_samples)
clusters_dbscan = dbscan.fit_predict(v_hg)

# Mediane dei cluster sulle intersezioni
cluster0 = v_hg[clusters_dbscan == 0]
cluster1 = v_hg[clusters_dbscan == 1]
centro0 = np.median(cluster0, axis=0)
centro1 = np.median(cluster1, axis=0)

print("="*70)
print("DBSCAN CLUSTERING SULLE INTERSEZIONI")
print("="*70)
print(f"Epsilon: {epsilon}, Min samples: {min_samples}")
print(f"Cluster 0: {len(cluster0)} intersezioni, mediana: {centro0}")
print(f"Cluster 1: {len(cluster1)} intersezioni, mediana: {centro1}")
print(f"Outliers (cluster -1): {np.sum(clusters_dbscan == -1)} intersezioni")
print("="*70)

# ============================================================
# Assegnazione RETTE ai cluster (distanza retta-mediana cluster)
# ============================================================

eventi_dbscan = []
dist_to_centro0 = []
dist_to_centro1 = []

threshold = 5  # mm

for r in rette_hg:
    p0 = r["p0"]
    d = r["d"]
    
    # Normalizzazione
    norm_d = np.linalg.norm(d)
    if norm_d == 0:
        eventi_dbscan.append(-1)  # invalida
        dist_to_centro0.append(np.inf)
        dist_to_centro1.append(np.inf)
        continue
    d_unit = d / norm_d
    
    # Distanze dalla retta ai centri dei cluster
    v0 = centro0 - p0
    v1 = centro1 - p0
    dist0 = abs(v0[0] * d_unit[1] - v0[1] * d_unit[0])
    dist1 = abs(v1[0] * d_unit[1] - v1[1] * d_unit[0])
    
    dist_to_centro0.append(dist0)
    dist_to_centro1.append(dist1)
    
    # Assegna al cluster più vicino (con soglia)
    if dist0 < threshold and dist0 < dist1:
        eventi_dbscan.append(0)
    elif dist1 < threshold and dist1 < dist0:
        eventi_dbscan.append(1)
    else:
        eventi_dbscan.append(-1)  # outlier (troppo lontano da entrambi)

eventi_dbscan = np.array(eventi_dbscan)
dist_to_centro0 = np.array(dist_to_centro0)
dist_to_centro1 = np.array(dist_to_centro1)

print(f"\nAssegnazione RETTE ai cluster (soglia={threshold} mm):")
print(f"  Cluster 0: {np.sum(eventi_dbscan == 0)} rette")
print(f"  Cluster 1: {np.sum(eventi_dbscan == 1)} rette")
print(f"  Outliers: {np.sum(eventi_dbscan == -1)} rette")

# ============================================================
# Estrazione verità Monte Carlo
# ============================================================

eventi_mc = []

for r in rette_hg:
    eventi_mc.append(r["event"])
    
eventi_mc = np.array(eventi_mc)

unique_events_mc = np.unique(eventi_mc)
print(f"\nEventi Monte Carlo presenti: {unique_events_mc}")
print(f"Numero di eventi: {len(unique_events_mc)}")

# ============================================================
# Confronto: DBSCAN vs Monte Carlo
# ============================================================

# Filtra solo le rette che DBSCAN ha assegnato a un cluster (non outliers)
mask_validi = eventi_dbscan != -1

eventi_dbscan_validi = eventi_dbscan[mask_validi]
eventi_mc_validi = eventi_mc[mask_validi]

# Metriche di clustering
ari = adjusted_rand_score(eventi_mc_validi, eventi_dbscan_validi)
fmi = fowlkes_mallows_score(eventi_mc_validi, eventi_dbscan_validi)

print("\n" + "="*70)
print("CONFRONTO: DBSCAN vs MONTE CARLO")
print("="*70)
print(f"Rette totali: {len(eventi_mc)}")
print(f"Rette assegnate da DBSCAN: {np.sum(mask_validi)}")
print(f"Rette outlier DBSCAN: {np.sum(~mask_validi)}")
print(f"\nAdjusted Rand Index: {ari:.3f}")
print(f"Fowlkes-Mallows Index: {fmi:.3f}")
print(f"(1.0 = perfetto accordo, 0.0 = casuale)")

# Analisi per cluster
print("\n" + "-"*70)
print("ANALISI PUREZZA CLUSTER:")
print("-"*70)

for cluster_id in [0, 1]:
    mask_cluster = eventi_dbscan_validi == cluster_id
    if np.sum(mask_cluster) == 0:
        continue
    
    eventi_in_cluster = eventi_mc_validi[mask_cluster]
    unique, counts = np.unique(eventi_in_cluster, return_counts=True)
    
    print(f"\nCluster DBSCAN {cluster_id}:")
    print(f"  Totale rette: {len(eventi_in_cluster)}")
    for ev, count in zip(unique, counts):
        percentage = 100 * count / len(eventi_in_cluster)
        print(f"    Evento MC {ev}: {count} rette ({percentage:.1f}%)")
    
    # Purezza del cluster (% della classe più rappresentata)
    purezza = np.max(counts) / len(eventi_in_cluster)
    print(f"  Purezza: {purezza:.1%}")

print("="*70)

# ============================================================
# Plot 1: Confronto side-by-side
# ============================================================

# Crea colormap dinamica per gli eventi MC
from matplotlib.colors import ListedColormap
n_events = len(unique_events_mc)
if n_events == 2:
    colors_mc = ["royalblue", "orange"]
else:
    # Se ci sono più di 2 eventi, usa una colormap
    colors_mc = plt.cm.tab10(np.linspace(0, 1, n_events))

# Mappa evento -> colore
event_to_color = {ev: colors_mc[i] for i, ev in enumerate(unique_events_mc)}

colori_dbscan = {0: "red", 1: "green", -1: "gray"}

# Lunghezza rette
xmin, xmax = np.min(xfp), np.max(xfp)
ymin, ymax = np.min(yfp), np.max(yfp)
diag = np.sqrt((xmax - xmin)**2 + (ymax - ymin)**2)
L = 0.40 * diag

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# ─── Plot 1: Eventi Monte Carlo (verità) ───────────────────
ax = axes[0]
ax.plot(xfp, yfp, 'k-', linewidth=1.5, zorder=1)

for i, r in enumerate(rette_hg):
    p0 = r["p0"]
    d = r["d"]
    col = event_to_color[eventi_mc[i]]
    
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color=col, linewidth=2.5, alpha=0.85, zorder=3)
    ax.scatter(p0[0], p0[1], s=100, color=col, edgecolor="white", linewidth=2, zorder=4)

ax.set_title("VERITÀ MONTE CARLO (EVENT)", fontsize=15, fontweight='bold', pad=12)
ax.set_xlim(-250, 250)
ax.set_ylim(-250, 250)
ax.set_aspect('equal')
ax.set_xlabel('x [mm]', fontsize=13)
ax.set_ylabel('y [mm]', fontsize=13)
ax.grid(True, linestyle=':', alpha=0.3)

from matplotlib.patches import Patch
legend_mc = [Patch(facecolor=event_to_color[ev], label=f'MC Event {ev}') 
             for ev in unique_events_mc]
ax.legend(handles=legend_mc, loc='upper right', fontsize=12, framealpha=0.95)

# ─── Plot 2: Clustering DBSCAN ─────────────────────────────
ax = axes[1]
ax.plot(xfp, yfp, 'k-', linewidth=1.5, zorder=1)

for i, r in enumerate(rette_hg):
    p0 = r["p0"]
    d = r["d"]
    cluster = eventi_dbscan[i]
    col = colori_dbscan[cluster]
    
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    
    alpha = 0.85 if cluster != -1 else 0.4
    lw = 2.5 if cluster != -1 else 1.5
    
    ax.plot([x1, x2], [y1, y2], color=col, linewidth=lw, alpha=alpha, zorder=3)
    ax.scatter(p0[0], p0[1], s=100, color=col, edgecolor="white", linewidth=2, zorder=4)

# Mediane cluster
ax.scatter(centro0[0], centro0[1], marker='+', s=400, c='red', linewidth=3, zorder=5)
ax.scatter(centro1[0], centro1[1], marker='+', s=400, c='green', linewidth=3, zorder=5)

ax.set_title(f"DBSCAN CLUSTERING (ARI={ari:.3f})", fontsize=15, fontweight='bold', pad=12)
ax.set_xlim(-250, 250)
ax.set_ylim(-250, 250)
ax.set_aspect('equal')
ax.set_xlabel('x [mm]', fontsize=13)
ax.set_ylabel('y [mm]', fontsize=13)
ax.grid(True, linestyle=':', alpha=0.3)

legend_dbscan = [
    Patch(facecolor='red', label='DBSCAN Cluster 0'),
    Patch(facecolor='green', label='DBSCAN Cluster 1'),
    Patch(facecolor='gray', label='Outliers')
]
ax.legend(handles=legend_dbscan, loc='upper right', fontsize=12, framealpha=0.95)

plt.tight_layout()
plt.show()

# ============================================================
# Plot 2: Colora le rette in base a purezza del cluster
# ============================================================

# Per ogni cluster, trova l'evento MC più rappresentato
cluster_main_event = {}
for cluster_id in [0, 1]:
    mask_cluster = (eventi_dbscan == cluster_id)
    if np.sum(mask_cluster) == 0:
        continue
    eventi_in_cluster = eventi_mc[mask_cluster]
    unique, counts = np.unique(eventi_in_cluster, return_counts=True)
    # L'evento principale è quello più frequente
    cluster_main_event[cluster_id] = unique[np.argmax(counts)]

print(f"\nEvento principale per cluster:")
print(f"  Cluster 0 -> Evento MC {cluster_main_event.get(0, 'N/A')}")
print(f"  Cluster 1 -> Evento MC {cluster_main_event.get(1, 'N/A')}")

fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(xfp, yfp, 'k-', linewidth=1.5, zorder=1)

n_corrette = 0
n_sbagliate = 0
n_outliers = 0

for i, r in enumerate(rette_hg):
    p0 = r["p0"]
    d = r["d"]
    evento_mc = eventi_mc[i]
    cluster_dbscan = eventi_dbscan[i]
    
    if cluster_dbscan == -1:
        # Outlier
        col = 'purple'
        alpha = 0.5
        lw = 2.0
        marker_size = 80
        n_outliers += 1
    else:
        # Controlla se è nel cluster "giusto" (quello dove il suo evento è maggioritario)
        evento_principale = cluster_main_event.get(cluster_dbscan, None)
        
        if evento_mc == evento_principale:
            # Corretto: stesso evento dell'evento principale del cluster
            col = event_to_color[evento_mc]
            alpha = 0.85
            lw = 2.5
            marker_size = 100
            n_corrette += 1
        else:
            # Errore: evento diverso dall'evento principale del cluster
            col = 'red'
            alpha = 1.0
            lw = 4.5
            marker_size = 180
            n_sbagliate += 1
    
    x1 = p0[0] - L * d[0]
    y1 = p0[1] - L * d[1]
    x2 = p0[0] + L * d[0]
    y2 = p0[1] + L * d[1]
    ax.plot([x1, x2], [y1, y2], color=col, linewidth=lw, alpha=alpha, zorder=3)
    ax.scatter(p0[0], p0[1], s=marker_size, color=col, 
               edgecolor="white", linewidth=2, zorder=4)


            
ax.set_xlim(-250, 250)
ax.set_ylim(-250, 250)
ax.set_aspect('equal')
ax.set_xlabel('x [mm]', fontsize=13)
ax.set_ylabel('y [mm]', fontsize=13)
ax.grid(True, linestyle=':', alpha=0.3)

legend_elements = []
for ev in unique_events_mc:
    legend_elements.append(Patch(facecolor=event_to_color[ev], 
                                 label=f'MC Event {ev} (cluster corretto)'))
legend_elements.append(Patch(facecolor='red', label=f'Cluster sbagliato ({n_sbagliate})'))
legend_elements.append(Patch(facecolor='purple', label=f'Outliers DBSCAN ({n_outliers})'))

ax.legend(handles=legend_elements, loc='upper right', fontsize=11, framealpha=0.95)

print(f"\nRette nel cluster corretto: {n_corrette}")
print(f"Rette nel cluster sbagliato: {n_sbagliate}")
print(f"Rette outlier: {n_outliers}")

plt.tight_layout()
plt.show()
# Out:
# /home/matfra/miniconda3/envs/astrienv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/matfra/miniconda3/envs/astrienv/lib/python3.10/site-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# ...
# DBSCAN CLUSTERING SULLE INTERSEZIONI
# ...
# Epsilon: 20, Min samples: 6
# Cluster 0: 6 intersezioni, mediana: [-42.46982585 204.48368297]
# Cluster 1: 0 intersezioni, mediana: [nan nan]
# Outliers (cluster -1): 29 intersezioni
# ...
#
# Assegnazione RETTE ai cluster (soglia=5 mm):
#   Cluster 0: 0 rette
#   Cluster 1: 0 rette
#   Outliers: 9 rette
#
# Eventi Monte Carlo presenti: [0 1]
# Numero di eventi: 2
#
# ...
# CONFRONTO: DBSCAN vs MONTE CARLO
# ...
# Rette totali: 9
# Rette assegnate da DBSCAN: 0
# Rette outlier DBSCAN: 9
#
# Adjusted Rand Index: 1.000
# Fowlkes-Mallows Index: 0.000
# (1.0 = perfetto accordo, 0.0 = casuale)
#
# ...
